# %% [markdown]
# # NII / EVE Simulator – Demo Notebook
#
# This notebook provides an interactive walkthrough of the simulator's components:
#
# 1. **Data loading** – Fetch the current yield curve from FRED
# 2. **Balance sheet** – Inspect and override the default bank balance sheet
# 3. **Rate scenarios** – Visualise parallel shifts, twists, and flatteners
# 4. **Repricing gap** – Gap ladder and duration analysis
# 5. **NII sensitivity** – Income impact across scenarios
# 6. **EVE sensitivity** – Economic value impact across scenarios

# %%
# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 5)

# %%
# Project imports (run from repo root or add to sys.path)
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..'))

import config
from data.fred_loader import fetch_yield_curve
from models.balance_sheet import BalanceSheet
from models.repricing import build_repricing_gap
from models.risk_metrics import nii_sensitivity_table, eve_sensitivity_table
from scenarios.rate_scenarios import build_scenarios

# %% [markdown]
# ## 1. Fetch Yield Curve

# %%
# TODO: replace with your FRED API key in config.py
# base_curve = fetch_yield_curve()
# base_curve

# %% [markdown]
# ## 2. Build Balance Sheet

# %%
# TODO: uncomment once BalanceSheet.from_config() is implemented
# bs = BalanceSheet.from_config()
# bs.to_dataframe()

# %% [markdown]
# ## 3. Rate Scenarios

# %%
# TODO: uncomment once build_scenarios() is implemented
# scenarios = build_scenarios(base_curve)
# for name, scenario in scenarios.items():
#     plt.plot(scenario.shocked_curve.index, scenario.shocked_curve.values * 100, label=scenario.label)
# plt.xlabel('Tenor (years)')
# plt.ylabel('Rate (%)')
# plt.title('Shocked Yield Curves')
# plt.legend()
# plt.show()

# %% [markdown]
# ## 4. Repricing Gap

# %%
# TODO: uncomment once build_repricing_gap() is implemented
# gap_ladder = build_repricing_gap(bs)
# gap_ladder

# %% [markdown]
# ## 5. NII Sensitivity

# %%
# TODO: uncomment once nii_sensitivity_table() is implemented
# nii_table = nii_sensitivity_table(bs, scenarios)
# nii_table

# %% [markdown]
# ## 6. EVE Sensitivity

# %%
# TODO: uncomment once eve_sensitivity_table() is implemented
# eve_table = eve_sensitivity_table(bs, scenarios)
# eve_table
